# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HxVcr8Bqcwp6UoUDsXER")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(20)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-20 in yolov8:: 100%|██████████| 756/756 [00:00<00:00, 13377.38it/s]

# %%
import shutil

shutil.move(src="football-players-detection-20/train",
            dst="football-players-detection-20/footbal-players-detection-20/train")
shutil.move(src="football-players-detection-20/valid",
            dst="football-players-detection-20/footbal-players-detection-20/valid")
shutil.move(src="football-players-detection-20/test",
            dst="football-players-detection-20/footbal-players-detection-20/test")
# Out:
# 'football-players-detection-20/footbal-players-detection-20/test'

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640

# %%
import os
from ultralytics import YOLO

# Load the YOLOv5x pretrained model
model = YOLO("yolov5x.pt")

# Construct the data.yaml path dynamically
data_path = os.path.join(dataset.location, "data.yaml")

# Train the model
results = model.train(
    task="detect",
    data=data_path,
    epochs=100,
    imgsz=640
)
